# %%
import pandas as pd 
import numpy as np


smc_Av = 0.22
smc_extinction_coeff = [3.522767303652845, 3.062652780996107, 2.7436011426496876, 1.746851127566682, 1.4073996800012445, 1.0353852912271932, 0.5911705440475679]
smc_Alam = np.array(smc_extinction_coeff) * smc_Av
vega2ab = [1.7315030439941026, 1.6877065055589147, 1.4892220221800545, 0.7600980615093107, -0.10816681468099532, 0.01548950348946665,  0.4469155013218913]

lmc_Av = 0.38
lmc_extinction_coeff = [2.644541680555541, 2.7233599880955124, 2.3536449902431045, 1.5634790597438197, 1.3170082045312625, 1.0333402844940784, 0.7366865234305091]
lmc_Alam = np.array(lmc_extinction_coeff) * lmc_Av




# Set up dataframe dict
df_dict = {'filter': ['UVW2', 'UVM2', 'UVW1', 'U', 'B', 'V', 'I'],
           'A_lambda (LMC)': lmc_Alam,
           'A_lambda (SMC)': smc_Alam,
           'Vega to AB': vega2ab}
df = pd.DataFrame(df_dict)
df.to_latex(index=False)
# Out:
# '\\begin{tabular}{lrrr}\n\\toprule\nfilter & A_lambda (LMC) & A_lambda (SMC) & Vega to AB \\\\\n\\midrule\nUVW2 & 1.004926 & 0.775009 & 1.731503 \\\\\nUVM2 & 1.034877 & 0.673784 & 1.687707 \\\\\nUVW1 & 0.894385 & 0.603592 & 1.489222 \\\\\nU & 0.594122 & 0.384307 & 0.760098 \\\\\nB & 0.500463 & 0.309628 & -0.108167 \\\\\nV & 0.392669 & 0.227785 & 0.015490 \\\\\nI & 0.279941 & 0.130058 & 0.446916 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
df
# Out:
#   filter  A_lambda (LMC)  A_lambda (SMC)  Vega to AB
# 0   UVW2        1.004926        0.775009    1.731503
# 1   UVM2        1.034877        0.673784    1.687707
# 2   UVW1        0.894385        0.603592    1.489222
# 3      U        0.594122        0.384307    0.760098
# 4      B        0.500463        0.309628   -0.108167
# 5      V        0.392669        0.227785    0.015490
# 6      I        0.279941        0.130058    0.446916
